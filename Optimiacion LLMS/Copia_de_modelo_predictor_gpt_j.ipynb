# %%
from openai import OpenAI

# Inicializar el cliente de OpenAI con la clave API
client = OpenAI(api_key="")

# Definir una función para procesar una consulta con contexto
def process_query_with_context(user_query, context):
    # Formar el prompt con el contexto y la consulta del usuario
    prompt = f"{context}\n**Usuario:** {user_query}"

    # Realizar la solicitud de completación al modelo de OpenAI
    response = client.chat.completions.create(
        model="gpt-4o",
        messages=[{"role": "user", "content": prompt}],
        temperature=1,
        max_tokens=256,
        top_p=1,
        frequency_penalty=0,
        presence_penalty=0
    )

    # Retornar el contenido de la respuesta generada por el modelo
    return response.choices[0].message.content  # Changed to dot notation

# Ejemplo de uso
user_query = "cuánto vale b?"
context = "La fecha de hoy es 2024-07-02. b vale 9."

# Procesar la consulta con el contexto proporcionado
respuesta = process_query_with_context(user_query, context)

# Imprimir la respuesta generada por el modelo
print(respuesta)

# %%
pip

# %%
# !pip install transformers

# %%
# Instalar las bibliotecas requeridas (asegúrate de que ya están instaladas)
# !pip install transformers

# Importar las bibliotecas necesarias
import torch
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer

# Intentar cargar un modelo GPT-J más pequeño para reducir los requisitos de memoria
try:
  model = AutoModelForSeq2SeqLM.from_pretrained("EleutherAI/gpt-j-6B", torch_dtype=torch.float16)
except:
  # Si falla la carga del modelo grande, intentar con uno más pequeño
  model = AutoModelForSeq2SeqLM.from_pretrained("EleutherAI/gpt-j-6B-384")

tokenizer = AutoTokenizer.from_pretrained(model.name_or_path)

# ... resto del código para generar texto (igual que antes)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-d67e9e816d27> in <cell line: 9>()
#       9 try:
# ---> 10   model = AutoModelForSeq2SeqLM.from_pretrained("EleutherAI/gpt-j-6B", torch_dtype=torch.float16)
#      11 except:
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/auto/auto_factory.py in from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     565             )
# --> 566         raise ValueError(
#     567             f"Unrecognized configuration class {config.__class__} for this kind of AutoModel: {cls.__name__}.\n"
#
# ValueError: Unrecognized configuration class <class 'transformers.models.gptj.configuration_gptj.GPTJConfig'> for this kind of AutoModel: AutoModelForSeq2SeqLM.
# ...

# %%
# Instalar las bibliotecas requeridas (asegúrate de que ya están instaladas)
# !pip install transformers torch

# Importar las bibliotecas necesarias
import torch
from transformers import GPTJForCausalLM, AutoTokenizer

# Intentar cargar un modelo GPT-J más pequeño para reducir los requisitos de memoria
try:
    model = GPTJForCausalLM.from_pretrained("EleutherAI/gpt-j-6B", torch_dtype=torch.float16)
except:
    # Si falla la carga del modelo grande, intentar con uno más pequeño
    model = GPTJForCausalLM.from_pretrained("EleutherAI/gpt-neo-125M")

tokenizer = AutoTokenizer.from_pretrained("EleutherAI/gpt-j-6B")

# Función para generar texto
def generate_text(prompt, max_length=100):
    input_ids = tokenizer.encode(prompt, return_tensors="pt")

    # Generar texto
    output = model.generate(input_ids, max_length=max_length, num_return_sequences=1, no_repeat_ngram_size=2)

    # Decodificar y devolver el texto generado
    generated_text = tokenizer.decode(output[0], skip_special_tokens=True)
    return generated_text

# Ejemplo de uso
prompt = "Una vez en un bosque encantado,"
generated_text = generate_text(prompt)
print(generated_text)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(

# %%
# Instalar las bibliotecas requeridas
#!pip install transformers torch bitsandbytes accelerate

import torch
from transformers import AutoTokenizer, AutoModelForCausalLM

# Configurar el modelo para usar cuantización de 8 bits
model_name = "EleutherAI/gpt-j-6B"
tokenizer = AutoTokenizer.from_pretrained(model_name)

# Cargar el modelo con cuantización de 8 bits
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    device_map="auto",
    load_in_8bit=True,
)

# Función para generar texto
def generate_text(prompt, max_length=100):
    inputs = tokenizer(prompt, return_tensors="pt").to(model.device)

    # Generar texto
    with torch.no_grad():
        outputs = model.generate(
            **inputs,
            max_length=max_length,
            num_return_sequences=1,
            no_repeat_ngram_size=2,
            do_sample=True,
            temperature=0.7
        )

    # Decodificar y devolver el texto generado
    generated_text = tokenizer.decode(outputs[0], skip_special_tokens=True)
    return generated_text

# Ejemplo de uso
prompt = "Uque es el sol"
generated_text = generate_text(prompt)
print(generated_text)

# Liberar memoria
del model
torch.cuda.empty_cache()
# Out:
# The `load_in_4bit` and `load_in_8bit` arguments are deprecated and will be removed in the future versions. Please, pass a `BitsAndBytesConfig` object in `quantization_config` argument instead.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Uque es el sol más grande del planeta. Muchos medios de comunicación han contado el misterio de la máscara solar, la forma en que el Sol alimenta el planeto, y que gracias al halo de hidrógeno que sale de su superficie, se puede conocer directamente.
#
# El Sol es un sistema de unos 150.000

# %%
# Instalar las bibliotecas requeridas
#!pip install transformers torch bitsandbytes accelerate

import torch
from transformers import AutoTokenizer, AutoModelForCausalLM

# Configurar el modelo para usar cuantización de 8 bits
model_name = "EleutherAI/gpt-j-6B"
tokenizer = AutoTokenizer.from_pretrained(model_name)

# Cargar el modelo con cuantización de 8 bits
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    device_map="auto",
    load_in_8bit=True,
)

# Función para generar texto
def generate_text(prompt, max_length=100):
    inputs = tokenizer(prompt, return_tensors="pt").to(model.device)

    # Generar texto
    with torch.no_grad():
        outputs = model.generate(
            **inputs,
            max_length=max_length,
            num_return_sequences=1,
            no_repeat_ngram_size=2,
            do_sample=True,
            temperature=0.7
        )

    # Decodificar y devolver el texto generado
    generated_text = tokenizer.decode(outputs[0], skip_special_tokens=True)
    return generated_text

# Ejemplo de uso
prompt = "Uque es el sol"
generated_text = generate_text(prompt)
print(generated_text)

# Liberar memoria
del model
torch.cuda.empty_cache()
# Out:
# The `load_in_4bit` and `load_in_8bit` arguments are deprecated and will be removed in the future versions. Please, pass a `BitsAndBytesConfig` object in `quantization_config` argument instead.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-7225de2e019f> in <cell line: 12>()
#      10
#      11 # Cargar el modelo con cuantización de 8 bits
# ---> 12 model = AutoModelForCausalLM.from_pretrained(
#      13     model_name,
#      14     device_map="auto",
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/auto/auto_factory.py in from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     561         elif type(config) in cls._model_mapping.keys():
#     562             model_class = _get_model_class(config, cls._model_mapping)
# --> 563             return model_class.from_pretrained(
# ...

# %%
# Instalar las bibliotecas requeridas
#!pip install transformers torch bitsandbytes accelerate

import torch
from transformers import AutoTokenizer, AutoModelForCausalLM

# Configurar el modelo para usar cuantización de 8 bits
model_name = "EleutherAI/gpt-j-6B"
tokenizer = AutoTokenizer.from_pretrained(model_name)

# Cargar el modelo con cuantización de 8 bits
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    device_map="auto",
    load_in_8bit=True,
)

# Función para generar texto
def generate_text(prompt, max_length=100):
    inputs = tokenizer(prompt, return_tensors="pt").to(model.device)

    # Generar texto
    with torch.no_grad():
        outputs = model.generate(
            **inputs,
            max_length=max_length,
            num_return_sequences=1,
            no_repeat_ngram_size=2,
            do_sample=True,
            temperature=0.7
        )

    # Decodificar y devolver el texto generado
    generated_text = tokenizer.decode(outputs[0], skip_special_tokens=True)
    return generated_text

# Ejemplo de uso
prompt = "Uque es el sol"
generated_text = generate_text(prompt)
print(generated_text)

# Liberar memoria
del model
torch.cuda.empty_cache()
# Out:
# The `load_in_4bit` and `load_in_8bit` arguments are deprecated and will be removed in the future versions. Please, pass a `BitsAndBytesConfig` object in `quantization_config` argument instead.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-cd46eb7ddf5f> in <cell line: 12>()
#      10
#      11 # Cargar el modelo con cuantización de 8 bits
# ---> 12 model = AutoModelForCausalLM.from_pretrained(
#      13     model_name,
#      14     device_map="auto",
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/auto/auto_factory.py in from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     561         elif type(config) in cls._model_mapping.keys():
#     562             model_class = _get_model_class(config, cls._model_mapping)
# --> 563             return model_class.from_pretrained(
# ...

# %%
# Out:
# The `load_in_4bit` and `load_in_8bit` arguments are deprecated and will be removed in the future versions. Please, pass a `BitsAndBytesConfig` object in `quantization_config` argument instead.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-7225de2e019f> in <cell line: 12>()
#      10
#      11 # Cargar el modelo con cuantización de 8 bits
# ---> 12 model = AutoModelForCausalLM.from_pretrained(
#      13     model_name,
#      14     device_map="auto",
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/auto/auto_factory.py in from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     561         elif type(config) in cls._model_mapping.keys():
#     562             model_class = _get_model_class(config, cls._model_mapping)
# --> 563             return model_class.from_pretrained(
# ...

# %%
# Instalar las bibliotecas requeridas
#!pip install transformers torch bitsandbytes accelerate

import torch
from transformers import AutoTokenizer, AutoModelForCausalLM

# Configurar el modelo para usar cuantización de 8 bits
model_name = "EleutherAI/gpt-j-6B"
tokenizer = AutoTokenizer.from_pretrained(model_name)

# Cargar el modelo con cuantización de 8 bits
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    device_map="auto",
    load_in_8bit=True,
)

# Función para generar texto
def generate_text(prompt, max_length=100):
    inputs = tokenizer(prompt, return_tensors="pt").to(model.device)

    # Generar texto
    with torch.no_grad():
        outputs = model.generate(
            **inputs,
            max_length=max_length,
            num_return_sequences=1,
            no_repeat_ngram_size=2,
            do_sample=True,
            temperature=0.7
        )

    # Decodificar y devolver el texto generado
    generated_text = tokenizer.decode(outputs[0], skip_special_tokens=True)
    return generated_text

# Ejemplo de uso
prompt = "que es el un gato"
generated_text = generate_text(prompt)
print(generated_text)

# Liberar memoria
del model
torch.cuda.empty_cache()
# Out:
# The `load_in_4bit` and `load_in_8bit` arguments are deprecated and will be removed in the future versions. Please, pass a `BitsAndBytesConfig` object in `quantization_config` argument instead.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-d6e32a75dcd6> in <cell line: 12>()
#      10
#      11 # Cargar el modelo con cuantización de 8 bits
# ---> 12 model = AutoModelForCausalLM.from_pretrained(
#      13     model_name,
#      14     device_map="auto",
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/auto/auto_factory.py in from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     561         elif type(config) in cls._model_mapping.keys():
#     562             model_class = _get_model_class(config, cls._model_mapping)
# --> 563             return model_class.from_pretrained(
# ...

# %%
# Instalar las bibliotecas requeridas
# !pip install transformers torch accelerate

import torch
from transformers import AutoTokenizer, AutoModelForCausalLM

# Configurar el modelo para usar cuantización de 8 bits
model_name = "EleutherAI/gpt-j-6B"
tokenizer = AutoTokenizer.from_pretrained(model_name)

# Verificar si CUDA está disponible y configurar el dispositivo
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Cargar el modelo con cuantización de 8 bits
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    device_map="auto",
    load_in_8bit=True,
).to(device)

# Función para generar texto
def generate_text(prompt, max_length=100, temperature=0.7, top_k=50, top_p=0.9):
    inputs = tokenizer(prompt, return_tensors="pt").to(device)

    # Generar texto
    with torch.no_grad():
        outputs = model.generate(
            **inputs,
            max_length=max_length,
            num_return_sequences=1,
            no_repeat_ngram_size=2,
            do_sample=True,
            temperature=temperature,
            top_k=top_k,
            top_p=top_p
        )

    # Decodificar y devolver el texto generado
    generated_text = tokenizer.decode(outputs[0], skip_special_tokens=True)
    return generated_text

# Ejemplo de uso
prompt = "¿Qué es el sol?"
generated_text = generate_text(prompt, max_length=100, temperature=0.7, top_k=50, top_p=0.9)
print(generated_text)

# Liberar memoria
del model
torch.cuda.empty_cache()
# Out:
# The `load_in_4bit` and `load_in_8bit` arguments are deprecated and will be removed in the future versions. Please, pass a `BitsAndBytesConfig` object in `quantization_config` argument instead.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-cada33b75926> in <cell line: 15>()
#      13
#      14 # Cargar el modelo con cuantización de 8 bits
# ---> 15 model = AutoModelForCausalLM.from_pretrained(
#      16     model_name,
#      17     device_map="auto",
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/auto/auto_factory.py in from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     561         elif type(config) in cls._model_mapping.keys():
#     562             model_class = _get_model_class(config, cls._model_mapping)
# --> 563             return model_class.from_pretrained(
# ...

# %%
cuantizacion 4 bits

# %%
# Instalar las bibliotecas requeridas
# !pip install -q transformers torch bitsandbytes accelerate

import torch
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig

# Configurar el modelo para usar cuantización de 4 bits
model_name = "EleutherAI/gpt-j-6B"
tokenizer = AutoTokenizer.from_pretrained(model_name)

# Configuración de cuantización
quantization_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_compute_dtype=torch.float16,
    bnb_4bit_use_double_quant=True,
    bnb_4bit_quant_type="nf4"
)

# Cargar el modelo con cuantización de 4 bits y offloading
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    quantization_config=quantization_config,
    device_map="auto",
    torch_dtype=torch.float16,
    low_cpu_mem_usage=True,
)

# Función para generar texto
def generate_text(prompt, max_length=100):
    inputs = tokenizer(prompt, return_tensors="pt").to(model.device)

    # Generar texto
    with torch.no_grad():
        outputs = model.generate(
            **inputs,
            max_length=max_length,
            num_return_sequences=1,
            no_repeat_ngram_size=2,
            do_sample=True,
            temperature=0.7
        )

    # Decodificar y devolver el texto generado
    generated_text = tokenizer.decode(outputs[0], skip_special_tokens=True)
    return generated_text

# Ejemplo de uso
prompt = "Una vez en un bosque encantado,"
generated_text = generate_text(prompt)
print(generated_text)

# Liberar memoria
del model
torch.cuda.empty_cache()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-3-082ef8a7079a> in <cell line: 20>()
#      18
#      19 # Cargar el modelo con cuantización de 4 bits y offloading
# ---> 20 model = AutoModelForCausalLM.from_pretrained(
#      21     model_name,
#      22     quantization_config=quantization_config,
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/auto/auto_factory.py in from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     561         elif type(config) in cls._model_mapping.keys():
#     562             model_class = _get_model_class(config, cls._model_mapping)
# --> 563             return model_class.from_pretrained(
#     564                 pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     565             )
#
# ...

# %%
# Instalar las bibliotecas requeridas
#!pip install -q transformers torch

import torch
from transformers import AutoTokenizer, AutoModelForCausalLM

# Configurar para usar CPU
device = torch.device("cpu")

# Usar un modelo más pequeño para mejorar el rendimiento en CPU
model_name = "EleutherAI/gpt-neo-125M"  # Puedes intentar con "EleutherAI/gpt-neo-1.3B" si tu CPU lo permite
tokenizer = AutoTokenizer.from_pretrained(model_name)

# Cargar el modelo en CPU
print("Cargando el modelo. Esto puede tardar unos minutos...")
model = AutoModelForCausalLM.from_pretrained(model_name, torch_dtype=torch.float32)
model = model.to(device)
print("Modelo cargado exitosamente.")

# Función para generar texto
def generate_text(prompt, max_length=100):
    inputs = tokenizer(prompt, return_tensors="pt").to(device)

    # Generar texto
    with torch.no_grad():
        outputs = model.generate(
            **inputs,
            max_length=max_length,
            num_return_sequences=1,
            no_repeat_ngram_size=2,
            do_sample=True,
            temperature=0.7
        )

    # Decodificar y devolver el texto generado
    generated_text = tokenizer.decode(outputs[0], skip_special_tokens=True)
    return generated_text

# Ejemplo de uso
prompt = "Una vez en un bosque encantado,"
print("Generando texto. Esto puede tardar un poco en CPU...")
generated_text = generate_text(prompt)
print("Texto generado:")
print(generated_text)

# Liberar memoria
del model
torch.cuda.empty_cache()
# Out:
# tokenizer_config.json:   0%|          | 0.00/727 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.11M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/357 [00:00<?, ?B/s]
# Cargando el modelo. Esto puede tardar unos minutos...
# config.json:   0%|          | 0.00/1.01k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/526M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/119 [00:00<?, ?B/s]
# Modelo cargado exitosamente.
# Generando texto. Esto puede tardar un poco en CPU...
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Texto generado:
# Una vez en un bosque encantado, los aparatos que trabajan en el barrio de la casa de Boca Juniors, una verdadera espléndida, alrededor del 80% de los salarios, han sido colocados en algunos casos por las carreras del país y en las cuatro ciudades del mundo.
#
# ...
